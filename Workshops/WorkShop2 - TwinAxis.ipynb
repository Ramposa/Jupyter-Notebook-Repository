# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

austin_weather = pd.read_csv('austin_weather.csv')

# %%
austin_weather.head()
# Out:
#          Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0  21/12/2013         74        60        45            67           49
# 1  22/12/2013         56        48        39            43           36
# 2  23/12/2013         58        45        32            31           27
# 3  24/12/2013         61        46        31            36           28
# 4  25/12/2013         58        50        41            44           40
#
#   DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  ...  \
# 0           43                  93                 75                 57  ...
# 1           28                  93                 68                 43  ...
# 2           23                  76                 52                 27  ...
# 3           21                  89                 56                 22  ...
# 4           36                  86                 71                 56  ...
#
# ...

# %%
austin_weather = austin_weather[['Date', 'TempAvgF', 'WindAvgMPH']].head(30)
austin_weather
#Extracting important details i.e. Date for the x-axis, TempAvgF, and WindAvgMPH for the different y-axis.
# Out:
#           Date  TempAvgF WindAvgMPH
# 0   21/12/2013        60          4
# 1   22/12/2013        48          6
# 2   23/12/2013        45          3
# 3   24/12/2013        46          4
# 4   25/12/2013        50          2
# 5   26/12/2013        48          3
# 6   27/12/2013        53          1
# 7   28/12/2013        51          2
# 8   29/12/2013        50          5
# 9   30/12/2013        40          5
# 10  31/12/2013        46          1
# 11  01/01/2014        54          4
# 12  02/01/2014        44          8
# 13  03/01/2014        43          4
# 14  04/01/2014        57          7
# 15  05/01/2014        47         10
# 16  06/01/2014        29          7
# 17  07/01/2014        35          5
# 18  08/01/2014        47          1
# 19  09/01/2014        62          3
# 20  10/01/2014        65          6
# 21  11/01/2014        62          3
# 22  12/01/2014        57          4
# 23  13/01/2014        57          7
# 24  14/01/2014        57          5
# ...

# %%
fig, ax_tempF = plt.subplots()
fig.set_figwidth(12)
fig.set_figheight(6)

ax_tempF.set_xlabel('Date')
ax_tempF.tick_params(axis='x', bottom=False, labelbottom=False)
ax_tempF.set_ylabel('Temp - F', color='red', size='x-large')
ax_tempF.tick_params(axis='y', labelcolor='red', labelsize='large')
ax_tempF.plot(austin_weather['Date'], austin_weather['TempAvgF'], color='red')

ax_precip=ax_tempF.twinx()
ax_precip.set_ylabel('Avg wind speed', color='blue', size='x-large')
ax_precip.tick_params(axis='y', labelcolor='blue', labelsize='large')
ax_precip.plot(austin_weather['Date'], austin_weather['WindAvgMPH'], color='blue')

# %%
def fah2cel(f):
    return (f-32)*5/9
#The function is defined for calculating different unit of data i.e. convert from Fahrenheit to Celsius.

# %%
#Subplot for plotting figure.
fig, ax_tempF = plt.subplots()

#Similar to fig=plt.figure(figsize-(12,6))
fig.set_figwidth(12)
fig.set_figheight(6)

# set x label which is common
ax_tempF.set_xlabel('Date')

# Bottom= false disable ticks and labelbottom disable x-axis labels
ax_tempF.tick_params(axis = 'x',
                    bottom=False,
                    labelbottom=False)

# set left y-axis label
ax_tempF.set_ylabel('Temp (F)',
                   color='red',
                   size='x-large')

# set labelcolor and labelsize to the left of the y-axis
ax_tempF.tick_params(axis='y',
                    labelcolor='red',
                    labelsize='large')

# plot AvgTemp on Y-axis to the left
ax_tempF.plot(austin_weather['Date'],
             austin_weather['TempAvgF'],
             color='green')

# twinaxis set the same x=axis for both plots.
ax_tempC = ax_tempF.twinx()
